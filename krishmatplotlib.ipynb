# %% [markdown]
# <a href="https://colab.research.google.com/github/krishks10/SimpleProject/blob/main/krishmatplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

xpts = np.array([80, 85, 90,])
ypts = np.array([40, 42.5, 45])

plt.plot(xpts, ypts)
plt.show()
